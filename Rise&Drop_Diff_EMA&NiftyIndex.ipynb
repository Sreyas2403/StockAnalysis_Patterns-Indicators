# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreyas2403/StockAnalysis_Patterns-Indicators/blob/main/Rise%26Drop_Diff_EMA%26NiftyIndex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance nsepython
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.41)
# Collecting nsepython
#   Downloading nsepython-2.93-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.25.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.4)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from nsepython) (1.13.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.7.4)
# Downloading nsepython-2.93-py3-none-any.whl (25 kB)
# Installing collected packages: nsepython
# Successfully installed nsepython-2.93

# %%
#version1: all rise,drop, ema, nse index in one plot
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from datetime import timedelta
import numpy as np
import matplotlib.dates as mdates

# List of 10 stock symbols on NSE
stock_symbols = ["RELIANCE.NS", "TCS.NS", "INFY.NS", "HDFCBANK.NS", "ICICIBANK.NS", "HINDUNILVR.NS", "KOTAKBANK.NS", "LT.NS", "SBIN.NS", "BHARTIARTL.NS"]

# Function to get closing prices
def get_closing_prices(symbols, date):
    closing_prices = {}
    for symbol in symbols:
        stock = yf.Ticker(symbol)
        history = stock.history(start=date, end=date + timedelta(days=1))
        if not history.empty:
            closing_prices[symbol] = history['Close'].values[0]
        else:
            closing_prices[symbol] = np.nan
    return closing_prices

# Function to adjust for non-trading days
def adjust_date(date):
    while True:
        closing_prices = get_closing_prices(["RELIANCE.NS"], date)
        if not pd.isna(closing_prices["RELIANCE.NS"]):
            return date
        date -= timedelta(days=1)

# Initialize lists to store results
dates = []
num_stocks_rise = []
num_stocks_drop = []
difference_rise_drop = []

# Define today's and yesterday's dates
today = datetime.date.today()
yesterday = today - timedelta(days=1)

# Check if it's before market opens (9 AM IST)
current_time = datetime.datetime.now().time()
if current_time < datetime.time(9, 0):
    today -= timedelta(days=1)
    yesterday -= timedelta(days=1)

# Adjust dates for non-trading days
today = adjust_date(today)
yesterday = adjust_date(yesterday)

# Loop for 365 days
for i in range(365):
    # Fetch closing prices
    yesterday_closing_prices = get_closing_prices(stock_symbols, yesterday)
    today_closing_prices = get_closing_prices(stock_symbols, today)

    # Calculate the number of stocks that have risen and dropped
    stocks_rise = 0
    stocks_drop = 0
    for symbol in stock_symbols:
        if not pd.isna(yesterday_closing_prices[symbol]) and not pd.isna(today_closing_prices[symbol]):
            if today_closing_prices[symbol] > yesterday_closing_prices[symbol]:
                stocks_rise += 1
            elif today_closing_prices[symbol] < yesterday_closing_prices[symbol]:
                stocks_drop += 1

    # Store results
    dates.append(today)
    num_stocks_rise.append(stocks_rise)
    num_stocks_drop.append(stocks_drop)
    difference_rise_drop.append(stocks_rise - stocks_drop)

    # Update dates for next iteration
    today = yesterday - timedelta(days=1)
    yesterday = today - timedelta(days=1)

    # Adjust dates for non-trading days
    today = adjust_date(today)
    yesterday = adjust_date(yesterday)

# Plot the results
fig, ax1 = plt.subplots(figsize=(20, 15))

ax1.bar(dates, num_stocks_rise, color='green', label='Stocks Rise', alpha=0.6)
ax1.bar(dates, num_stocks_drop, color='red', label='Stocks Drop', alpha=0.6)
ax1.plot(dates, difference_rise_drop, color='blue', label='Difference (Rise - Drop)')

# Format dates on x-axis
ax1.xaxis.set_major_locator(mdates.MonthLocator())
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))

# Fetch Nifty index data for the same period
nifty = yf.Ticker("^NSEI")
nifty_history = nifty.history(start=dates[-1], end=dates[0])
nifty_closing_prices = nifty_history['Close']

ax2 = ax1.twinx()
ax2.plot(nifty_closing_prices.index, nifty_closing_prices, color='brown', label='Nifty Index')

# Calculate and plot EMA lines
ema_20 = nifty_closing_prices.ewm(span=20, adjust=False).mean()
ema_100 = nifty_closing_prices.ewm(span=100, adjust=False).mean()
ema_200 = nifty_closing_prices.ewm(span=200, adjust=False).mean()

ax2.plot(ema_20.index, ema_20, color='yellow', label='EMA 20')
ax2.plot(ema_100.index, ema_100, color='purple', label='EMA 100')
ax2.plot(ema_200.index, ema_200, color='pink', label='EMA 200')

ax1.set_xlabel('Date')
ax1.set_ylabel('Number of Stocks')
ax2.set_ylabel('Nifty Index')

fig.autofmt_xdate()
fig.tight_layout()

fig.legend(loc='upper left', bbox_to_anchor=(0.1,0.9), bbox_transform=ax1.transAxes)
plt.title('Stock Analysis Over 365 Days')
plt.show()
# Out:
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-28 -> 2024-07-29)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-27 -> 2024-07-28)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-28 -> 2024-07-29)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-27 -> 2024-07-28)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-21 -> 2024-07-22)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-20 -> 2024-07-21)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-21 -> 2024-07-22)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-20 -> 2024-07-21)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-20 -> 2024-07-21)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-20 -> 2024-07-21)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-17 -> 2024-07-18)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-17 -> 2024-07-18)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-14 -> 2024-07-15)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-13 -> 2024-07-14)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-14 -> 2024-07-15)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-13 -> 2024-07-14)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-07 -> 2024-07-08)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-06 -> 2024-07-07)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-07 -> 2024-07-08)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-06 -> 2024-07-07)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-06 -> 2024-07-07)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-06 -> 2024-07-07)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-30 -> 2024-07-01)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-29 -> 2024-06-30)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-29 -> 2024-06-30)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-30 -> 2024-07-01)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-29 -> 2024-06-30)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-29 -> 2024-06-30)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-23 -> 2024-06-24)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-22 -> 2024-06-23)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-23 -> 2024-06-24)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-22 -> 2024-06-23)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-22 -> 2024-06-23)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-22 -> 2024-06-23)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-17 -> 2024-06-18)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-16 -> 2024-06-17)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-15 -> 2024-06-16)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-17 -> 2024-06-18)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-16 -> 2024-06-17)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-15 -> 2024-06-16)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-09 -> 2024-06-10)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-08 -> 2024-06-09)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-09 -> 2024-06-10)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-08 -> 2024-06-09)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-08 -> 2024-06-09)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-08 -> 2024-06-09)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-02 -> 2024-06-03)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-01 -> 2024-06-02)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-02 -> 2024-06-03)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-01 -> 2024-06-02)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-01 -> 2024-06-02)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-01 -> 2024-06-02)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-26 -> 2024-05-27)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-25 -> 2024-05-26)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-25 -> 2024-05-26)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-26 -> 2024-05-27)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-25 -> 2024-05-26)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-25 -> 2024-05-26)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-20 -> 2024-05-21)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-19 -> 2024-05-20)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-18 -> 2024-05-19)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-20 -> 2024-05-21)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-19 -> 2024-05-20)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-18 -> 2024-05-19)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-12 -> 2024-05-13)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-11 -> 2024-05-12)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-12 -> 2024-05-13)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-11 -> 2024-05-12)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-11 -> 2024-05-12)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-11 -> 2024-05-12)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-05 -> 2024-05-06)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-04 -> 2024-05-05)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-05 -> 2024-05-06)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-04 -> 2024-05-05)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-04 -> 2024-05-05)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-04 -> 2024-05-05)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-01 -> 2024-05-02)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-05-01 -> 2024-05-02)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-28 -> 2024-04-29)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-27 -> 2024-04-28)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-28 -> 2024-04-29)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-27 -> 2024-04-28)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-21 -> 2024-04-22)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-20 -> 2024-04-21)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-20 -> 2024-04-21)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-21 -> 2024-04-22)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-20 -> 2024-04-21)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-20 -> 2024-04-21)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-17 -> 2024-04-18)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-17 -> 2024-04-18)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-14 -> 2024-04-15)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-13 -> 2024-04-14)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-14 -> 2024-04-15)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-13 -> 2024-04-14)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-11 -> 2024-04-12)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-11 -> 2024-04-12)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-07 -> 2024-04-08)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-06 -> 2024-04-07)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-06 -> 2024-04-07)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-07 -> 2024-04-08)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-06 -> 2024-04-07)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-04-06 -> 2024-04-07)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-31 -> 2024-04-01)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-30 -> 2024-03-31)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-29 -> 2024-03-30)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-31 -> 2024-04-01)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-30 -> 2024-03-31)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-29 -> 2024-03-30)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-30 -> 2024-03-31)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-29 -> 2024-03-30)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-30 -> 2024-03-31)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-29 -> 2024-03-30)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-25 -> 2024-03-26)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-24 -> 2024-03-25)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-25 -> 2024-03-26)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-24 -> 2024-03-25)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-23 -> 2024-03-24)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-24 -> 2024-03-25)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-23 -> 2024-03-24)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-23 -> 2024-03-24)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-24 -> 2024-03-25)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-23 -> 2024-03-24)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-17 -> 2024-03-18)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-16 -> 2024-03-17)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-16 -> 2024-03-17)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-17 -> 2024-03-18)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-16 -> 2024-03-17)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-16 -> 2024-03-17)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-10 -> 2024-03-11)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-09 -> 2024-03-10)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-08 -> 2024-03-09)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-10 -> 2024-03-11)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-09 -> 2024-03-10)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-08 -> 2024-03-09)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-09 -> 2024-03-10)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-08 -> 2024-03-09)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-09 -> 2024-03-10)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-08 -> 2024-03-09)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-03 -> 2024-03-04)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-02 -> 2024-03-03)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-03 -> 2024-03-04)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-03-02 -> 2024-03-03)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-25 -> 2024-02-26)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-24 -> 2024-02-25)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-24 -> 2024-02-25)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-25 -> 2024-02-26)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-24 -> 2024-02-25)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-24 -> 2024-02-25)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-18 -> 2024-02-19)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-17 -> 2024-02-18)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-17 -> 2024-02-18)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-18 -> 2024-02-19)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-17 -> 2024-02-18)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-17 -> 2024-02-18)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-11 -> 2024-02-12)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-10 -> 2024-02-11)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-10 -> 2024-02-11)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-11 -> 2024-02-12)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-10 -> 2024-02-11)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-10 -> 2024-02-11)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-04 -> 2024-02-05)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-03 -> 2024-02-04)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-04 -> 2024-02-05)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-03 -> 2024-02-04)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-03 -> 2024-02-04)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-02-03 -> 2024-02-04)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-28 -> 2024-01-29)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-27 -> 2024-01-28)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-26 -> 2024-01-27)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-28 -> 2024-01-29)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-27 -> 2024-01-28)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-26 -> 2024-01-27)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-27 -> 2024-01-28)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-26 -> 2024-01-27)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-27 -> 2024-01-28)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-26 -> 2024-01-27)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-22 -> 2024-01-23)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-21 -> 2024-01-22)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-20 -> 2024-01-21)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-22 -> 2024-01-23)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-21 -> 2024-01-22)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-20 -> 2024-01-21)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-21 -> 2024-01-22)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-20 -> 2024-01-21)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-21 -> 2024-01-22)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-20 -> 2024-01-21)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-14 -> 2024-01-15)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-13 -> 2024-01-14)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-13 -> 2024-01-14)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-14 -> 2024-01-15)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-13 -> 2024-01-14)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-13 -> 2024-01-14)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-07 -> 2024-01-08)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-06 -> 2024-01-07)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-07 -> 2024-01-08)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-06 -> 2024-01-07)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-06 -> 2024-01-07)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-01-06 -> 2024-01-07)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2023-12-31 -> 2024-01-01)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2023-12-30 -> 2023-12-31)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2023-12-30 -> 2023-12-31)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2023-12
01-27)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2023-01-26 -> 2023-01-27)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2023-01-22 -> 2023-01-23)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2023-01-21 -> 2023-01-22)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2023-01-21 -> 2023-01-22)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2023-01-22 -> 2023-01-23)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2023-01-21 -> 2023-01-22)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2023-01-21 -> 2023-01-22)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2023-01-15 -> 2023-01-16)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2023-01-14 -> 2023-01-15)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2023-01-14 -> 2023-01-15)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2023-01-15 -> 2023-01-16)
# ...
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-08-14 -> 2022-08-15)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-08-13 -> 2022-08-14)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-08-09 -> 2022-08-10)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-08-09 -> 2022-08-10)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-08-07 -> 2022-08-08)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-08-06 -> 2022-08-07)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-08-07 -> 2022-08-08)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-08-06 -> 2022-08-07)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-08-06 -> 2022-08-07)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-08-06 -> 2022-08-07)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-31 -> 2022-08-01)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-30 -> 2022-07-31)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-30 -> 2022-07-31)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-31 -> 2022-08-01)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-30 -> 2022-07-31)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-30 -> 2022-07-31)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-24 -> 2022-07-25)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-23 -> 2022-07-24)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-24 -> 2022-07-25)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-23 -> 2022-07-24)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-23 -> 2022-07-24)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-23 -> 2022-07-24)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-17 -> 2022-07-18)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-16 -> 2022-07-17)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-17 -> 2022-07-18)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-16 -> 2022-07-17)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-16 -> 2022-07-17)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-16 -> 2022-07-17)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-10 -> 2022-07-11)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-09 -> 2022-07-10)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-10 -> 2022-07-11)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-09 -> 2022-07-10)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-09 -> 2022-07-10)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-09 -> 2022-07-10)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-03 -> 2022-07-04)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-02 -> 2022-07-03)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-02 -> 2022-07-03)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-03 -> 2022-07-04)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-02 -> 2022-07-03)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-07-02 -> 2022-07-03)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-26 -> 2022-06-27)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-25 -> 2022-06-26)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-25 -> 2022-06-26)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-26 -> 2022-06-27)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-25 -> 2022-06-26)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-25 -> 2022-06-26)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-19 -> 2022-06-20)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-18 -> 2022-06-19)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-18 -> 2022-06-19)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-19 -> 2022-06-20)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-18 -> 2022-06-19)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-18 -> 2022-06-19)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-12 -> 2022-06-13)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-11 -> 2022-06-12)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-12 -> 2022-06-13)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-11 -> 2022-06-12)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-11 -> 2022-06-12)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-11 -> 2022-06-12)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-05 -> 2022-06-06)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-04 -> 2022-06-05)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-05 -> 2022-06-06)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-04 -> 2022-06-05)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-04 -> 2022-06-05)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-06-04 -> 2022-06-05)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-29 -> 2022-05-30)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-28 -> 2022-05-29)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-28 -> 2022-05-29)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-29 -> 2022-05-30)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-28 -> 2022-05-29)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-28 -> 2022-05-29)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-22 -> 2022-05-23)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-21 -> 2022-05-22)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-21 -> 2022-05-22)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-22 -> 2022-05-23)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-21 -> 2022-05-22)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-21 -> 2022-05-22)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-15 -> 2022-05-16)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-14 -> 2022-05-15)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-14 -> 2022-05-15)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-15 -> 2022-05-16)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-14 -> 2022-05-15)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-14 -> 2022-05-15)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-08 -> 2022-05-09)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-07 -> 2022-05-08)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-07 -> 2022-05-08)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-08 -> 2022-05-09)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-07 -> 2022-05-08)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-07 -> 2022-05-08)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-03 -> 2022-05-04)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-03 -> 2022-05-04)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-01 -> 2022-05-02)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-30 -> 2022-05-01)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-30 -> 2022-05-01)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-05-01 -> 2022-05-02)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-30 -> 2022-05-01)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-30 -> 2022-05-01)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-24 -> 2022-04-25)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-23 -> 2022-04-24)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-24 -> 2022-04-25)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-23 -> 2022-04-24)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-23 -> 2022-04-24)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-23 -> 2022-04-24)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-17 -> 2022-04-18)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-16 -> 2022-04-17)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-15 -> 2022-04-16)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-17 -> 2022-04-18)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-16 -> 2022-04-17)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-15 -> 2022-04-16)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-14 -> 2022-04-15)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-16 -> 2022-04-17)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-15 -> 2022-04-16)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-14 -> 2022-04-15)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-14 -> 2022-04-15)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-16 -> 2022-04-17)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-15 -> 2022-04-16)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-14 -> 2022-04-15)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-10 -> 2022-04-11)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-09 -> 2022-04-10)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-09 -> 2022-04-10)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-10 -> 2022-04-11)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-09 -> 2022-04-10)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-09 -> 2022-04-10)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-03 -> 2022-04-04)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-02 -> 2022-04-03)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-03 -> 2022-04-04)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-02 -> 2022-04-03)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-02 -> 2022-04-03)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-04-02 -> 2022-04-03)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-27 -> 2022-03-28)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-26 -> 2022-03-27)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-26 -> 2022-03-27)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-27 -> 2022-03-28)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-26 -> 2022-03-27)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-26 -> 2022-03-27)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-20 -> 2022-03-21)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-19 -> 2022-03-20)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-18 -> 2022-03-19)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-20 -> 2022-03-21)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-19 -> 2022-03-20)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-18 -> 2022-03-19)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-19 -> 2022-03-20)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-18 -> 2022-03-19)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-19 -> 2022-03-20)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-18 -> 2022-03-19)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-13 -> 2022-03-14)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-12 -> 2022-03-13)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-13 -> 2022-03-14)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-12 -> 2022-03-13)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-06 -> 2022-03-07)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-05 -> 2022-03-06)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-05 -> 2022-03-06)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-06 -> 2022-03-07)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-05 -> 2022-03-06)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-05 -> 2022-03-06)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-01 -> 2022-03-02)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-03-01 -> 2022-03-02)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-02-27 -> 2022-02-28)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-02-26 -> 2022-02-27)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-02-26 -> 2022-02-27)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-02-27 -> 2022-02-28)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-02-26 -> 2022-02-27)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-02-26 -> 2022-02-27)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-02-20 -> 2022-02-21)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-02-19 -> 2022-02-20)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-02-19 -> 2022-02-20)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-02-20 -> 2022-02-21)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-02-19 -> 2022-02-20)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-02-19 -> 2022-02-20)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-02-13 -> 2022-02-14)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-02-12 -> 2022-02-13)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2022-02-12 -> 2022-02-13)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-02-13 -> 2022-02-14)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-02-12 -> 2022-02-13)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2022-02-12 -> 2022-02-13)

# %%
#version2: subplot1: rise, drop, diff ; subplot2: nse index, ema
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from datetime import timedelta
import numpy as np
import matplotlib.dates as mdates

# List of 10 stock symbols on NSE
stock_symbols = ["RELIANCE.NS", "TCS.NS", "INFY.NS", "HDFCBANK.NS", "ICICIBANK.NS", "HINDUNILVR.NS", "KOTAKBANK.NS", "LT.NS", "SBIN.NS", "BHARTIARTL.NS"]

# Function to get closing prices
def get_closing_prices(symbols, date):
    closing_prices = {}
    for symbol in symbols:
        stock = yf.Ticker(symbol)
        history = stock.history(start=date, end=date + timedelta(days=1))
        if not history.empty:
            closing_prices[symbol] = history['Close'].values[0]
        else:
            closing_prices[symbol] = np.nan
    return closing_prices

# Function to adjust for non-trading days
def adjust_date(date):
    while True:
        closing_prices = get_closing_prices(["RELIANCE.NS"], date)
        if not pd.isna(closing_prices["RELIANCE.NS"]):
            return date
        date -= timedelta(days=1)

# Initialize lists to store results
dates = []
num_stocks_rise = []
num_stocks_drop = []
difference_rise_drop = []

# Define today's and yesterday's dates
today = datetime.date.today()
yesterday = today - timedelta(days=1)

# Check if it's before market opens (9 AM IST)
current_time = datetime.datetime.now().time()
if current_time < datetime.time(9, 0):
    today -= timedelta(days=1)
    yesterday -= timedelta(days=1)

# Adjust dates for non-trading days
today = adjust_date(today)
yesterday = adjust_date(yesterday)

# Loop for 365 days
for i in range(365):
    # Fetch closing prices
    yesterday_closing_prices = get_closing_prices(stock_symbols, yesterday)
    today_closing_prices = get_closing_prices(stock_symbols, today)

    # Calculate the number of stocks that have risen and dropped
    stocks_rise = 0
    stocks_drop = 0
    for symbol in stock_symbols:
        if not pd.isna(yesterday_closing_prices[symbol]) and not pd.isna(today_closing_prices[symbol]):
            if today_closing_prices[symbol] > yesterday_closing_prices[symbol]:
                stocks_rise += 1
            elif today_closing_prices[symbol] < yesterday_closing_prices[symbol]:
                stocks_drop += 1

    # Store results
    dates.append(today)
    num_stocks_rise.append(stocks_rise)
    num_stocks_drop.append(stocks_drop)
    difference_rise_drop.append(stocks_rise - stocks_drop)

    # Update dates for next iteration
    today = yesterday - timedelta(days=1)
    yesterday = today - timedelta(days=1)

    # Adjust dates for non-trading days
    today = adjust_date(today)
    yesterday = adjust_date(yesterday)

# Create subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 12), sharex=True)

# Plot number of stocks rising and dropping
ax1.bar(dates, num_stocks_rise, color='green', label='Stocks Rise', alpha=0.6, width=0.4, align='center')
ax1.bar(dates, num_stocks_drop, color='red', label='Stocks Drop', alpha=0.6, width=0.4, align='center')
ax1.plot(dates, difference_rise_drop, color='blue', label='Difference (Rise - Drop)')
ax1.set_ylabel('Number of Stocks')
ax1.legend(loc='upper left')
ax1.set_ylim([0, 10])

# Fetch Nifty index data for the same period
nifty = yf.Ticker("^NSEI")
nifty_history = nifty.history(start=dates[-1], end=dates[0])
nifty_closing_prices = nifty_history['Close']

# Plot Nifty index and EMA lines
ax2.plot(nifty_closing_prices.index, nifty_closing_prices, color='brown', label='Nifty Index')

# Calculate and plot EMA lines
ema_20 = nifty_closing_prices.ewm(span=20, adjust=False).mean()
ema_100 = nifty_closing_prices.ewm(span=100, adjust=False).mean()
ema_200 = nifty_closing_prices.ewm(span=200, adjust=False).mean()

ax2.plot(ema_20.index, ema_20, color='yellow', label='EMA 20')
ax2.plot(ema_100.index, ema_100, color='purple', label='EMA 100')
ax2.plot(ema_200.index, ema_200, color='pink', label='EMA 200')

ax2.set_ylabel('Nifty Index')
ax2.legend(loc='upper left')

# Format dates on x-axis
ax2.xaxis.set_major_locator(mdates.MonthLocator())
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))

fig.autofmt_xdate()
fig.tight_layout()

fig.suptitle('Stock Analysis Over 365 Days', y=0.95)
plt.show()
# Out:
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-28 -> 2024-07-29)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-27 -> 2024-07-28)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-28 -> 2024-07-29)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-27 -> 2024-07-28)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-21 -> 2024-07-22)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-20 -> 2024-07-21)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-21 -> 2024-07-22)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-20 -> 2024-07-21)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-20 -> 2024-07-21)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-20 -> 2024-07-21)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-17 -> 2024-07-18)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-17 -> 2024-07-18)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-14 -> 2024-07-15)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-13 -> 2024-07-14)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-14 -> 2024-07-15)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-13 -> 2024-07-14)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-07 -> 2024-07-08)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-07 -> 2024-07-08)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-06 -> 2024-07-07)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-06 -> 2024-07-07)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-06 -> 2024-07-07)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-07-06 -> 2024-07-07)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-30 -> 2024-07-01)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-29 -> 2024-06-30)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-29 -> 2024-06-30)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-30 -> 2024-07-01)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-29 -> 2024-06-30)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-29 -> 2024-06-30)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-23 -> 2024-06-24)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-22 -> 2024-06-23)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-22 -> 2024-06-23)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-23 -> 2024-06-24)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-22 -> 2024-06-23)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-22 -> 2024-06-23)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-17 -> 2024-06-18)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-16 -> 2024-06-17)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-15 -> 2024-06-16)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-17 -> 2024-06-18)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-16 -> 2024-06-17)
# $RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06-15 -> 2024-06-16)
# ERROR:yfinance:$RELIANCE.NS: possibly delisted; No price data found  (1d 2024-06